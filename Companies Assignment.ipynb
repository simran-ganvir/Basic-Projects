# %%
pip install tabula-py
# Out:
# ...
#
# ...

# %%
import tabula as tb

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\simra'

# %%
df = tb.convert_into("C:\\Users\\simra\\Downloads\\Companies Assignment - Data.pdf", "Company.csv", pages = "all")

# %%
df1=pd.read_csv("Company.csv")

# %%
df1
# Out:
#      Unnamed: 0  Administration  Marketing Spend       State        Profit
# 0         Spend             NaN              NaN         NaN           NaN
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1024 rows x 5 columns]

# %%
df1.shape
# Out:
# (1024, 5)

# %%
df1 = df1.iloc[1: , :]

# %%
df1
# Out:
#      Unnamed: 0  Administration  Marketing Spend       State        Profit
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# 5     142107.34       91391.770      366168.4200     Florida  166187.94000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1023 rows x 5 columns]

# %%
df1_new = df1.rename(columns={'Unnamed: 0': 'R&D Spend'})

# %%
df1_new
# Out:
#       R&D Spend  Administration  Marketing Spend       State        Profit
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# 5     142107.34       91391.770      366168.4200     Florida  166187.94000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1023 rows x 5 columns]

# %%
df1 = df1_new
df1
# Out:
#       R&D Spend  Administration  Marketing Spend       State        Profit
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# 5     142107.34       91391.770      366168.4200     Florida  166187.94000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1023 rows x 5 columns]

# %%
df1.isnull().sum()
# Out:
# R&D Spend          25
# Administration     28
# Marketing Spend    29
# State              23
# Profit             23
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#       R&D Spend  Administration  Marketing Spend       State        Profit
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# 5     142107.34       91391.770      366168.4200     Florida  166187.94000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [987 rows x 5 columns]

# %%
df1.shape
# Out:
# (987, 5)

# %%
df1['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()   #### Sklearn Package

# %%
df1['State_cat1'] = lb.fit_transform(df1['State'])

# %%
df1
# Out:
#       R&D Spend  Administration  Marketing Spend       State        Profit  \
# 1      165349.2      136897.800      471784.1000    New York  192261.83000
# 2      162597.7      151377.590      443898.5300  California  191792.06000
# 3     153441.51      101145.550      407934.5400     Florida  191050.39000
# 4     144372.41      118671.850      383199.6200    New York  182901.99000
# 5     142107.34       91391.770      366168.4200     Florida  166187.94000
# ...         ...             ...              ...         ...           ...
# 1019      54135      118451.999      173232.6695  California   95279.96251
# 1020     134970      130390.080      329204.0228  California  164336.60550
# 1021  100275.47      241926.310      227142.8200  California  413956.48000
# 1022  128456.23      321652.140      281692.3200  California  333962.19000
# 1023  161181.72      270939.860      295442.1700    New York  476485.43000
#
#       State_cat1
# 1              2
# 2              0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
x=df1[['R&D Spend','Marketing Spend','Administration']]
y=df1['Profit']

# %%
model= LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([200413.17807185, 212535.19254472, 149248.88763639, 161608.61022018,
#        128900.92050003, 132419.77557482, 166220.86238597, 178644.97032217,
#        175894.96988248, 132718.21456838, 116943.33165837,  97301.57178859,
#        132805.54535921, 141047.83678295, 179542.5578194 , 139701.63980312,
#        119233.80098927, 155560.20438172, 121000.30255544, 136563.27978545,
#        112674.63050034, 157874.77452198, 121679.75353932,  99575.80488447,
#         83669.53725316, 121184.20894275, 131616.32964238, 130481.08168184,
#        167728.51014815, 133933.49134175,  89452.07207176, 129576.47765608,
#        101362.89157977,  82541.64015674,  93464.58500283,  20281.27531743,
#         48001.09869461,  81743.29491527,  43301.39449542,  52277.95389407,
#         72781.00920632, 105960.75128618,  58609.53786471,  74539.4208482 ,
#         70333.35837887, -21572.01578238,  53831.46967902, 123720.11747775,
# ...

# %%
model.coef_
# Out:
# array([0.53579177, 0.08450176, 1.10171662])

# %%
model.intercept_
# Out:
# -78868.72994473674

# %%
r2_score(y,model.predict(x))*100
# Out:
# 95.36852791410394

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=123)

# %%
model= LinearRegression()

# %%
model= model.fit(x_train,y_train)

# %%
model.coef_
# Out:
# array([0.61098033, 0.04953116, 1.04673824])

# %%
model.intercept_
# Out:
# -70494.5525184722

# %%
model.predict(x_train)
# Out:
# array([ 58496.90702582,  96675.45630527, 170127.07563579, 172262.69766249,
#         51850.64461671,  88688.40221849, 160642.502661  ,  79542.25641288,
#        143012.42628954, 185140.15406311,  79977.9922131 , 170037.51728559,
#        158321.73606563, 112894.12772754, 133725.37015224, 110011.03798526,
#        140822.55249655, 106169.5017641 , 129117.10491952, 102922.1507577 ,
#        178247.60619118,  62987.74117858, 162339.80553033,  91685.16209802,
#        141647.52261647,  91481.07245661, 126234.0151822 ,  88296.58444191,
#        163886.40926097, 152126.70991765,  55175.49802497, 140754.52258119,
#        170936.54528884, 162847.87691094, 127854.67669646, 129126.5774085 ,
#         49979.39186942, 161856.70720033,  99102.14296147,  70912.79342761,
#        141105.00580092, 164753.57508672,  64592.90223588,  50793.16719147,
#         74075.11668922,  98706.01951985, 136776.06547508,  86823.17744562,
# ...

# %%
r2_score(y_train,model.predict(x_train))*100
# Out:
# 96.50655120087947

# %%
model=model.fit(x_test,y_test)

# %%
model.coef_
# Out:
# array([0.24434328, 0.22310743, 1.30496986])

# %%
model.intercept_
# Out:
# -111129.03608882008

# %%
model.predict(x_test)
# Out:
# array([152814.44366503,  87138.90366423, 126964.81764215,  62067.4731471 ,
#        182934.16835115,  79915.65269838, 138373.1470192 , 112359.55335124,
#         65867.35782699, 162560.54042876, 163265.86141605, 179629.65678407,
#         58828.89574559,  64796.79677463, 112956.43024268, 106449.77845357,
#         82369.09414644, 143353.7720002 , 171381.82511907, 116903.79892392,
#        144124.15957995, 121933.87457288, 153171.87568029, 161999.23327419,
#        182963.66520674, 152916.81501009, 183336.71316881, 159994.316997  ,
#         95221.03266841, 182880.07183731, 182003.28341876, 178149.61045966,
#        105171.00454915, 105016.5799473 , 131017.16041009, 143267.88428325,
#        173860.42555717, 102995.1801725 , 121434.16371833, 142289.28382913,
#        106617.49450235,  51284.64993505, 115187.77803808, 172786.39434287,
#         58142.66085367,  78476.38131083,  93624.73409017, 170249.66765851,
# ...

# %%
r2_score(y_test,model.predict(x_test))*100
# Out:
# 93.28105246747342

# %% [markdown]
# ## As the test accuracy is less than train accuracy

# %%
import seaborn as sns

# %%
sns.relplot(data=df1,x='Marketing Spend',y='Administration')
sns.set_style('dark')

# %%
sns.barplot(data=df1,x='State',y='Profit',ci=None)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.countplot(df1['State'])
# Out:
# C:\Users\simra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
df1.corr()
# Out:
#                  Administration  Marketing Spend    Profit  State_cat1
# Administration         1.000000         0.529381  0.755755   -0.018705
# Marketing Spend        0.529381         1.000000  0.916650   -0.001526
# Profit                 0.755755         0.916650  1.000000   -0.006379
# State_cat1            -0.018705        -0.001526 -0.006379    1.000000

# %%
sns.heatmap(df1.corr(),annot=True,cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df1.Profit)
# Out:
# C:\Users\simra\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.boxplot(data=df1,x='State',y='Profit')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.relplot(data=df1,x='R&D Spend',y='Administration')

# %%
sns.pairplot(df1,vars=['R&D Spend','Administration','Marketing Spend','State','Profit'])

# %%
sns.histplot(df1.Profit)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.distplot(df1.Profit)
# Out:
# C:\Users\simra\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>
